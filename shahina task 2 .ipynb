# %%
# area of triangle
hieght=10
base=20
print(0.5*base*hieght)
# Out:
# 100.0

# %%
# area of square
side=20
side2=15
print(side*side2)
# Out:
# 300

# %%
# area of circle
radius=10
print(3.14*radius*radius)
# Out:
# 314.0
